# %%
import glob
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array, load_img
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-29 12:34:47.733296: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 12:34:47.775320: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 12:34:47.775355: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 12:34:47.776296: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 12:34:47.783149: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 12:34:48.884204: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load modlities of GRADE 3
G3_mod_1 = glob.glob(r"GRADE-3/flair/*.png") 
G3_mod_2 = glob.glob(r"GRADE-3/t1/*.png")
G3_mod_3 = glob.glob(r"GRADE-3/t2/*.png")

# Load modlities of GRADE 4
G4_mod_1 = glob.glob(r"GRADE-4/flair/*.png")
G4_mod_2 = glob.glob(r"GRADE-4/t1/*.png")
G4_mod_3 = glob.glob(r"GRADE-4/t2/*.png")

#G3 data place holder
G3_mod_1_data = []
G3_mod_2_data = []
G3_mod_3_data = []

#G4 data place holder
G4_mod_1_data = []
G4_mod_2_data = []
G4_mod_3_data = []


# Read GRADE-3 images and store them in placeholder
for img in G3_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_1_data.append(data)

for img in G3_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_2_data.append(data)

for img in G3_mod_3:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_3_data.append(data)

# Read GRADE-4 images and store them in placeholder
for img in G4_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_1_data.append(data)

for img in G4_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_2_data.append(data)
    
for img in G4_mod_3:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_3_data.append(data)

# %%
''' 
Create two array 'zeros' and 'ones' containing all zeros and ones respectively. 
Here the  zeros array serves the purpose of labels for GRADE-3 and the ones array serves the purpose of labels for GRADE-4
'''

zeros= np.zeros(len(G3_mod_1))

ones = np.ones(len(G4_mod_1))

# %%
# Combine same modalities of different GRADES for training. 

img_mod_1_data = G3_mod_1_data + G4_mod_1_data
img_mod_2_data = G3_mod_2_data + G4_mod_2_data
img_mod_3_data = G3_mod_3_data + G4_mod_3_data

img_mod_1_data = np.array(img_mod_1_data)
img_mod_2_data = np.array(img_mod_2_data)
img_mod_3_data = np.array(img_mod_3_data)

img_mod_1 = img_mod_1_data/255
img_mod_2 = img_mod_2_data/255
img_mod_3 = img_mod_3_data/255

print(img_mod_1_data.shape, img_mod_2_data.shape, img_mod_3_data.shape)
# Out:
# (2856, 224, 224, 3) (2856, 224, 224, 3) (2856, 224, 224, 3)

# %%
# Combining labels for both GRADES into one array/list

labels = np.append(zeros, ones)

# %%
# CNN model definition

model = Sequential()
model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 9)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# 2023-11-29 12:35:07.936734: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:07.984838: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:07.984911: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:07.992117: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:07.992200: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:07.992239: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:10.428048: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:10.428396: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:10.428435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-29 12:35:10.428582: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:35:10.428637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13535 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %%
# Compile the model

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", "Precision", "Recall", "AUC"])

# %%
comb = np.concatenate([img_mod_1, img_mod_2, img_mod_3], axis = -1)

print("Mod 1 and Mod 2 Shape: ", comb.shape)
print("Labels Shape: ", labels.shape)
# Out:
# Mod 1 and Mod 2 Shape:  (2856, 224, 224, 9)
# Labels Shape:  (2856,)

# %%
# Randomly and evenly(stratify) Spliting the data into train and test sets 
comb_train, comb_test, comb_labels_train, comb_labels_test = train_test_split(comb, labels, stratify=labels, test_size=0.2)

# Randomly and evenly(stratify) Spliting the train data into train and validation sets
comb_train, comb_val, comb_labels_train, comb_labels_val = train_test_split(comb_train, comb_labels_train, stratify=comb_labels_train, test_size=0.25)

'''
Training data = 60%
Validation data = 20%
Test data = 20%
'''
print(comb_train.shape, comb_labels_train.shape)
print(comb_val.shape, comb_labels_val.shape)
print(comb_test.shape, comb_labels_test.shape)
# Out:
# (1713, 224, 224, 9) (1713,)
# (571, 224, 224, 9) (571,)
# (572, 224, 224, 9) (572,)

# %%
# Train the model and store the results
history = model.fit(comb_train, comb_labels_train, batch_size = 32, epochs = 20, validation_data = (comb_val, comb_labels_val))
# Out:
# Epoch 1/20
# 2023-11-29 12:35:32.020807: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8905
# 2023-11-29 12:35:35.840475: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f5e380c39a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-29 12:35:35.840535: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-11-29 12:35:35.846873: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1701241536.007970    6127 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 54/54 [==============================] - 18s 128ms/step - loss: 0.8500 - accuracy: 0.5388 - precision: 0.5408 - recall: 0.5820 - auc: 0.5514 - val_loss: 0.6333 - val_accuracy: 0.6813 - val_precision: 0.6963 - val_recall: 0.6528 - val_auc: 0.7789
# Epoch 2/20
# 54/54 [==============================] - 3s 59ms/step - loss: 0.5537 - accuracy: 0.7221 - precision: 0.7201 - recall: 0.7367 - auc: 0.7913 - val_loss: 0.4185 - val_accuracy: 0.7968 - val_precision: 0.7312 - val_recall: 0.9444 - val_auc: 0.9005
# Epoch 3/20
# 54/54 [==============================] - 3s 60ms/step - loss: 0.3331 - accuracy: 0.8611 - precision: 0.8528 - recall: 0.8764 - auc: 0.9322 - val_loss: 0.2108 - val_accuracy: 0.9054 - val_precision: 0.9120 - val_recall: 0.8993 - val_auc: 0.9766
# Epoch 4/20
# 54/54 [==============================] - 3s 59ms/step - loss: 0.1743 - accuracy: 0.9340 - precision: 0.9313 - recall: 0.9388 - auc: 0.9832 - val_loss: 0.1225 - val_accuracy: 0.9545 - val_precision: 0.9367 - val_recall: 0.9757 - val_auc: 0.9936
# Epoch 5/20
# 54/54 [==============================] - 3s 62ms/step - loss: 0.0907 - accuracy: 0.9661 - precision: 0.9591 - recall: 0.9746 - auc: 0.9960 - val_loss: 0.0517 - val_accuracy: 0.9825 - val_precision: 0.9860 - val_recall: 0.9792 - val_auc: 0.9993
# Epoch 6/20
# 54/54 [==============================] - 3s 60ms/step - loss: 0.0303 - accuracy: 0.9930 - precision: 0.9919 - recall: 0.9942 - auc: 0.9996 - val_loss: 0.0443 - val_accuracy: 0.9877 - val_precision: 0.9763 - val_recall: 1.0000 - val_auc: 0.9999
# Epoch 7/20
# 54/54 [==============================] - 3s 58ms/step - loss: 0.0247 - accuracy: 0.9924 - precision: 0.9919 - recall: 0.9931 - auc: 0.9997 - val_loss: 0.0345 - val_accuracy: 0.9860 - val_precision: 0.9828 - val_recall: 0.9896 - val_auc: 0.9993
# Epoch 8/20
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0273 - accuracy: 0.9895 - precision: 0.9907 - recall: 0.9885 - auc: 0.9997 - val_loss: 0.0247 - val_accuracy: 0.9912 - val_precision: 0.9863 - val_recall: 0.9965 - val_auc: 0.9998
# Epoch 9/20
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0041 - accuracy: 0.9994 - precision: 0.9988 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9947 - val_precision: 0.9931 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 10/20
# 54/54 [==============================] - 3s 59ms/step - loss: 0.0017 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 11/20
# 54/54 [==============================] - 3s 59ms/step - loss: 5.2930e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 12/20
# 54/54 [==============================] - 3s 60ms/step - loss: 2.7218e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 13/20
# 54/54 [==============================] - 3s 59ms/step - loss: 2.1085e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 14/20
# 54/54 [==============================] - 3s 61ms/step - loss: 1.5300e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 15/20
# 54/54 [==============================] - 3s 60ms/step - loss: 1.1393e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 16/20
# 54/54 [==============================] - 3s 60ms/step - loss: 8.0628e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 17/20
# 54/54 [==============================] - 3s 62ms/step - loss: 6.2766e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 18/20
# 54/54 [==============================] - 3s 61ms/step - loss: 4.1088e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 19/20
# 54/54 [==============================] - 3s 60ms/step - loss: 2.9539e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000
# Epoch 20/20
# 54/54 [==============================] - 3s 62ms/step - loss: 2.1778e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9982 - val_precision: 1.0000 - val_recall: 0.9965 - val_auc: 1.0000

# %%
from keras.utils import plot_model
plot_model(model)

# %%
# Evaluate model on unseen (test) data

y_pred = model.predict(comb_test)
y_pred_binary = (y_pred > 0.5).astype(int) 

# Calculate accuracy
accuracy = accuracy_score(comb_labels_test, y_pred_binary)
precision = precision_score(comb_labels_test, y_pred_binary)
recall = recall_score(comb_labels_test, y_pred_binary)
f1 = f1_score(comb_labels_test, y_pred_binary)

# Confusion matrix
conf_matrix = confusion_matrix(comb_labels_test, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 18/18 [==============================] - 1s 49ms/step
# Accuracy: 0.9947552447552448
# Precision: 1.0
# Recall: 0.9896193771626297
# F1 Score: 0.994782608695652
# Confusion Matrix:
# [[283   0]
#  [  3 286]]

# %%
# Loss Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Loss curve- Overall")
plt.plot(history.history["loss"], label="overall training loss")
plt.plot(history.history["val_loss"], label="overall testing loss")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Accuracy Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Accuracy curve")
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Precision Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Precision curve")
plt.plot(history.history["precision"], label="training")
plt.plot(history.history["val_precision"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
#Recall curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Recall curve")
plt.plot(history.history["recall"], label="training")
plt.plot(history.history["val_recall"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# AUC curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("AUC curve")
plt.plot(history.history["auc"], label="training")
plt.plot(history.history["val_auc"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()
