# %%
import glob
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array, load_img
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-29 12:53:17.610867: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 12:53:17.652074: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 12:53:17.652106: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 12:53:17.653054: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 12:53:17.660114: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 12:53:18.695090: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load modlities of GRADE 3
G3_mod_1 = glob.glob(r"GRADE-3/flair/*.png") 
G3_mod_2 = glob.glob(r"GRADE-3/t1/*.png")
G3_mod_3 = glob.glob(r"GRADE-3/t2/*.png")
G3_mod_4 = glob.glob(r"GRADE-3/t1ce/*.png")

# Load modlities of GRADE 4
G4_mod_1 = glob.glob(r"GRADE-4/flair/*.png")
G4_mod_2 = glob.glob(r"GRADE-4/t1/*.png")
G4_mod_3 = glob.glob(r"GRADE-4/t2/*.png")
G4_mod_4 = glob.glob(r"GRADE-4/t1ce/*.png")

#G3 data place holder
G3_mod_1_data = []
G3_mod_2_data = []
G3_mod_3_data = []
G3_mod_4_data = []

#G4 data place holder
G4_mod_1_data = []
G4_mod_2_data = []
G4_mod_3_data = []
G4_mod_4_data = []


# Read GRADE-3 images and store them in placeholder
for img in G3_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_1_data.append(data)

for img in G3_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_2_data.append(data)

for img in G3_mod_3:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_3_data.append(data)
    
for img in G3_mod_4:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_4_data.append(data)

# Read GRADE-4 images and store them in placeholder
for img in G4_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_1_data.append(data)

for img in G4_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_2_data.append(data)
    
for img in G4_mod_3:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_3_data.append(data)
    
for img in G4_mod_4:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_4_data.append(data)

# %%
''' 
Create two array 'zeros' and 'ones' containing all zeros and ones respectively. 
Here the  zeros array serves the purpose of labels for GRADE-3 and the ones array serves the purpose of labels for GRADE-4
'''

zeros= np.zeros(len(G3_mod_1))

ones = np.ones(len(G4_mod_1))

# %%
# Combine same modalities of different GRADES for training. 

img_mod_1_data = G3_mod_1_data + G4_mod_1_data
img_mod_2_data = G3_mod_2_data + G4_mod_2_data
img_mod_3_data = G3_mod_3_data + G4_mod_3_data
img_mod_4_data = G3_mod_4_data + G4_mod_4_data

img_mod_1_data = np.array(img_mod_1_data)
img_mod_2_data = np.array(img_mod_2_data)
img_mod_3_data = np.array(img_mod_3_data)
img_mod_4_data = np.array(img_mod_4_data)

img_mod_1 = img_mod_1_data/255
img_mod_2 = img_mod_2_data/255
img_mod_3 = img_mod_3_data/255
img_mod_4 = img_mod_4_data/255

print(img_mod_1_data.shape, img_mod_2_data.shape, img_mod_3_data.shape, img_mod_4_data.shape)
# Out:
# (2856, 224, 224, 3) (2856, 224, 224, 3) (2856, 224, 224, 3) (2856, 224, 224, 3)

# %%
# Combining labels for both GRADES into one array/list

labels = np.append(zeros, ones)

# %%
# CNN model definition

model = Sequential()
model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 12)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# 2023-11-29 12:53:43.921549: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:43.959532: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:43.959630: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:43.965006: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:43.965125: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:43.965166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:46.185819: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:46.185909: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:46.185922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-29 12:53:46.185975: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:53:46.186006: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13535 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %%
# Compile the model

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", "Precision", "Recall", "AUC"])

# %%
comb = np.concatenate([img_mod_1, img_mod_2, img_mod_3, img_mod_4], axis = -1)

print("Mod 1 and Mod 2 Shape: ", comb.shape)
print("Labels Shape: ", labels.shape)
# Out:
# Mod 1 and Mod 2 Shape:  (2856, 224, 224, 12)
# Labels Shape:  (2856,)

# %%
# Randomly and evenly(stratify) Spliting the data into train and test sets 
comb_train, comb_test, comb_labels_train, comb_labels_test = train_test_split(comb, labels, stratify=labels, test_size=0.2)

# Randomly and evenly(stratify) Spliting the train data into train and validation sets
comb_train, comb_val, comb_labels_train, comb_labels_val = train_test_split(comb_train, comb_labels_train, stratify=comb_labels_train, test_size=0.25)

'''
Training data = 60%
Validation data = 20%
Test data = 20%
'''
print(comb_train.shape, comb_labels_train.shape)
print(comb_val.shape, comb_labels_val.shape)
print(comb_test.shape, comb_labels_test.shape)
# Out:
# (1713, 224, 224, 12) (1713,)
# (571, 224, 224, 12) (571,)
# (572, 224, 224, 12) (572,)

# %%
# Train the model and store the results
history = model.fit(comb_train, comb_labels_train, batch_size = 32, epochs = 20, validation_data = (comb_val, comb_labels_val))
# Out:
# Epoch 1/20
# 2023-11-29 12:54:16.693037: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8905
# 2023-11-29 12:54:20.891768: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f3a38171540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-29 12:54:20.891829: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-11-29 12:54:20.908118: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1701242661.109820    9437 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 54/54 [==============================] - 20s 144ms/step - loss: 0.7927 - accuracy: 0.5359 - precision: 0.5473 - recall: 0.4746 - auc: 0.5148 - val_loss: 0.6889 - val_accuracy: 0.5096 - val_precision: 0.6538 - val_recall: 0.0590 - val_auc: 0.6398
# Epoch 2/20
# 54/54 [==============================] - 3s 64ms/step - loss: 0.6752 - accuracy: 0.5616 - precision: 0.5699 - recall: 0.5416 - auc: 0.6002 - val_loss: 0.5904 - val_accuracy: 0.6795 - val_precision: 0.6721 - val_recall: 0.7118 - val_auc: 0.7533
# Epoch 3/20
# 54/54 [==============================] - 3s 63ms/step - loss: 0.5061 - accuracy: 0.7391 - precision: 0.7300 - recall: 0.7679 - auc: 0.8256 - val_loss: 0.4740 - val_accuracy: 0.7671 - val_precision: 0.6942 - val_recall: 0.9618 - val_auc: 0.9190
# Epoch 4/20
# 54/54 [==============================] - 3s 62ms/step - loss: 0.2734 - accuracy: 0.8792 - precision: 0.8706 - recall: 0.8938 - auc: 0.9559 - val_loss: 0.3152 - val_accuracy: 0.8634 - val_precision: 0.9646 - val_recall: 0.7569 - val_auc: 0.9602
# Epoch 5/20
# 54/54 [==============================] - 3s 61ms/step - loss: 0.1400 - accuracy: 0.9463 - precision: 0.9428 - recall: 0.9515 - auc: 0.9885 - val_loss: 0.1344 - val_accuracy: 0.9422 - val_precision: 0.9381 - val_recall: 0.9479 - val_auc: 0.9895
# Epoch 6/20
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0696 - accuracy: 0.9749 - precision: 0.9757 - recall: 0.9746 - auc: 0.9973 - val_loss: 0.1040 - val_accuracy: 0.9562 - val_precision: 0.9340 - val_recall: 0.9826 - val_auc: 0.9951
# Epoch 7/20
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0388 - accuracy: 0.9866 - precision: 0.9850 - recall: 0.9885 - auc: 0.9993 - val_loss: 0.0725 - val_accuracy: 0.9755 - val_precision: 0.9660 - val_recall: 0.9861 - val_auc: 0.9959
# Epoch 8/20
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0253 - accuracy: 0.9936 - precision: 0.9919 - recall: 0.9954 - auc: 0.9997 - val_loss: 0.0470 - val_accuracy: 0.9807 - val_precision: 0.9759 - val_recall: 0.9861 - val_auc: 0.9989
# Epoch 9/20
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0056 - accuracy: 0.9982 - precision: 0.9977 - recall: 0.9988 - auc: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9825 - val_precision: 0.9860 - val_recall: 0.9792 - val_auc: 0.9976
# Epoch 10/20
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0380 - accuracy: 0.9866 - precision: 0.9828 - recall: 0.9908 - auc: 0.9990 - val_loss: 0.1111 - val_accuracy: 0.9597 - val_precision: 0.9617 - val_recall: 0.9583 - val_auc: 0.9924
# Epoch 11/20
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0227 - accuracy: 0.9936 - precision: 0.9931 - recall: 0.9942 - auc: 0.9998 - val_loss: 0.0661 - val_accuracy: 0.9737 - val_precision: 0.9892 - val_recall: 0.9583 - val_auc: 0.9987
# Epoch 12/20
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0039 - accuracy: 0.9994 - precision: 1.0000 - recall: 0.9988 - auc: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9997
# Epoch 13/20
# 54/54 [==============================] - 4s 69ms/step - loss: 8.0332e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9997
# Epoch 14/20
# 54/54 [==============================] - 4s 69ms/step - loss: 3.1921e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998
# Epoch 15/20
# 54/54 [==============================] - 4s 66ms/step - loss: 1.5388e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998
# Epoch 16/20
# 54/54 [==============================] - 3s 65ms/step - loss: 1.1181e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998
# Epoch 17/20
# 54/54 [==============================] - 4s 68ms/step - loss: 9.0513e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998
# Epoch 18/20
# 54/54 [==============================] - 4s 67ms/step - loss: 7.0115e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998
# Epoch 19/20
# 54/54 [==============================] - 4s 67ms/step - loss: 5.7791e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998
# Epoch 20/20
# 54/54 [==============================] - 4s 66ms/step - loss: 4.7416e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9998

# %%
from keras.utils import plot_model
plot_model(model)

# %%
# Evaluate model on unseen (test) data

y_pred = model.predict(comb_test)
y_pred_binary = (y_pred > 0.5).astype(int) 

# Calculate accuracy
accuracy = accuracy_score(comb_labels_test, y_pred_binary)
precision = precision_score(comb_labels_test, y_pred_binary)
recall = recall_score(comb_labels_test, y_pred_binary)
f1 = f1_score(comb_labels_test, y_pred_binary)

# Confusion matrix
conf_matrix = confusion_matrix(comb_labels_test, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 18/18 [==============================] - 1s 62ms/step
# Accuracy: 0.9912587412587412
# Precision: 0.9863013698630136
# Recall: 0.9965397923875432
# F1 Score: 0.9913941480206541
# Confusion Matrix:
# [[279   4]
#  [  1 288]]

# %%
# Loss Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Loss curve- Overall")
plt.plot(history.history["loss"], label="overall training loss")
plt.plot(history.history["val_loss"], label="overall testing loss")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Accuracy Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Accuracy curve")
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Precision Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Precision curve")
plt.plot(history.history["precision"], label="training")
plt.plot(history.history["val_precision"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
#Recall curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Recall curve")
plt.plot(history.history["recall"], label="training")
plt.plot(history.history["val_recall"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# AUC curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("AUC curve")
plt.plot(history.history["auc"], label="training")
plt.plot(history.history["val_auc"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()
