# %%
import glob
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array, load_img
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-29 12:04:04.484952: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 12:04:04.530077: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 12:04:04.530111: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 12:04:04.531169: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 12:04:04.538812: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 12:04:05.773219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load modlities of GRADE 3
G3_mod_1 = glob.glob(r"GRADE-3/flair/*.png") 
G3_mod_2 = glob.glob(r"GRADE-3/t1/*.png")

# Load modlities of GRADE 4
G4_mod_1 = glob.glob(r"GRADE-4/flair/*.png")
G4_mod_2 = glob.glob(r"GRADE-4/t1/*.png")

#G3 data place holder
G3_mod_1_data = []
G3_mod_2_data = []

#G4 data place holder
G4_mod_1_data = []
G4_mod_2_data = []


# Read GRADE-3 images and store them in placeholder
for img in G3_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_1_data.append(data)

for img in G3_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_2_data.append(data)


# Read GRADE-4 images and store them in placeholder
for img in G4_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_1_data.append(data)

for img in G4_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_2_data.append(data)

# %%
''' 
Create two array 'zeros' and 'ones' containing all zeros and ones respectively. 
Here the  zeros array serves the purpose of labels for GRADE-3 and the ones array serves the purpose of labels for GRADE-4
'''

zeros= np.zeros(len(G3_mod_1))

ones = np.ones(len(G4_mod_1))

# %%
# Combine same modalities of different GRADES for training. 

img_mod_1_data = G3_mod_1_data + G4_mod_1_data
img_mod_2_data = G3_mod_2_data + G4_mod_2_data

img_mod_1_data = np.array(img_mod_1_data)
img_mod_2_data = np.array(img_mod_2_data)

img_mod_1 = img_mod_1_data/255
img_mod_2 = img_mod_2_data/255

print(img_mod_1_data.shape, img_mod_2_data.shape)
# Out:
# (2856, 224, 224, 3) (2856, 224, 224, 3)

# %%
# Combining labels for both GRADES into one array/list

labels = np.append(zeros, ones)

# %%
# CNN model definition

model = Sequential()
model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 6)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# 2023-11-29 12:04:19.357878: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:19.391623: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:19.391716: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:19.398195: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:19.398289: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:19.398336: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:22.117363: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:22.117454: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:22.117466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-29 12:04:22.117519: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:04:22.117541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13535 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %%
# Compile the model

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", "Precision", "Recall", "AUC"])

# %%
comb = np.concatenate([img_mod_1, img_mod_2], axis = -1)

print("Mod 1 and Mod 2 Shape: ", comb.shape)
print("Labels Shape: ", labels.shape)
# Out:
# Mod 1 and Mod 2 Shape:  (2856, 224, 224, 6)
# Labels Shape:  (2856,)

# %%
# Randomly and evenly(stratify) Spliting the data into train and test sets 
comb_train, comb_test, comb_labels_train, comb_labels_test = train_test_split(comb, labels, stratify=labels, test_size=0.2)

# Randomly and evenly(stratify) Spliting the train data into train and validation sets
comb_train, comb_val, comb_labels_train, comb_labels_val = train_test_split(comb_train, comb_labels_train, stratify=comb_labels_train, test_size=0.25)

'''
Training data = 60%
Validation data = 20%
Test data = 20%
'''
print(comb_train.shape, comb_labels_train.shape)
print(comb_val.shape, comb_labels_val.shape)
print(comb_test.shape, comb_labels_test.shape)
# Out:
# (1713, 224, 224, 6) (1713,)
# (571, 224, 224, 6) (571,)
# (572, 224, 224, 6) (572,)

# %%
# Train the model and store the results
history = model.fit(comb_train, comb_labels_train, batch_size = 32, epochs = 20, validation_data = (comb_val, comb_labels_val))
# Out:
# Epoch 1/20
# 2023-11-29 12:04:40.023160: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 
# Epoch 12/20
# 54/54 [==============================] - 2s 46ms/step - loss: 0.0303 - accuracy: 0.9883 - precision: 0.9840 - recall: 0.9931 - auc: 0.9989 - val_loss: 0.0165 - val_accuracy: 0.9930 - val_precision: 0.9897 - val_recall: 0.9965 - val_auc: 0.9999
# Epoch 13/20
# 54/54 [==============================] - 3s 48ms/step - loss: 0.0053 - accuracy: 0.9988 - precision: 0.9988 - recall: 0.9988 - auc: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9947 - val_precision: 0.9931 - val_recall: 0.9965 - val_auc: 0.9981
# Epoch 14/20
# 54/54 [==============================] - 3s 52ms/step - loss: 7.4951e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 15/20
# 54/54 [==============================] - 3s 56ms/step - loss: 2.4758e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 16/20
# 54/54 [==============================] - 3s 54ms/step - loss: 1.7302e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 17/20
# 54/54 [==============================] - 3s 54ms/step - loss: 1.3460e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 18/20
# 54/54 [==============================] - 3s 56ms/step - loss: 1.1276e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 19/20
# 54/54 [==============================] - 3s 58ms/step - loss: 9.1847e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 20/20
# 54/54 [==============================] - 3s 56ms/step - loss: 7.9404e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9982 - val_precision: 0.9965 - val_recall: 1.0000 - val_auc: 0.9982

# %%
from keras.utils import plot_model
plot_model(model)

# %%
# Evaluate model on unseen (test) data

y_pred = model.predict(comb_test)
y_pred_binary = (y_pred > 0.5).astype(int) 

# Calculate accuracy
accuracy = accuracy_score(comb_labels_test, y_pred_binary)
precision = precision_score(comb_labels_test, y_pred_binary)
recall = recall_score(comb_labels_test, y_pred_binary)
f1 = f1_score(comb_labels_test, y_pred_binary)

# Confusion matrix
conf_matrix = confusion_matrix(comb_labels_test, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 18/18 [==============================] - 1s 44ms/step
# Accuracy: 0.9947552447552448
# Precision: 0.9897260273972602
# Recall: 1.0
# F1 Score: 0.9948364888123925
# Confusion Matrix:
# [[280   3]
#  [  0 289]]

# %%
# Loss Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Loss curve- Overall")
plt.plot(history.history["loss"], label="overall training loss")
plt.plot(history.history["val_loss"], label="overall testing loss")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Accuracy Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Accuracy curve")
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Precision Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Precision curve")
plt.plot(history.history["precision"], label="training")
plt.plot(history.history["val_precision"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
#Recall curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Recall curve")
plt.plot(history.history["recall"], label="training")
plt.plot(history.history["val_recall"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# AUC curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("AUC curve")
plt.plot(history.history["auc"], label="training")
plt.plot(history.history["val_auc"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()
