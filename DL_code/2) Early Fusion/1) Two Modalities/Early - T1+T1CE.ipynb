# %%
import glob
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array, load_img
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-29 12:19:57.865977: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 12:19:57.919929: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 12:19:57.919968: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 12:19:57.921113: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 12:19:57.930761: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 12:19:58.996044: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load modlities of GRADE 3
G3_mod_1 = glob.glob(r"GRADE-3/t1/*.png") 
G3_mod_2 = glob.glob(r"GRADE-3/t1ce/*.png")

# Load modlities of GRADE 4
G4_mod_1 = glob.glob(r"GRADE-4/t1/*.png")
G4_mod_2 = glob.glob(r"GRADE-4/t1ce/*.png")

#G3 data place holder
G3_mod_1_data = []
G3_mod_2_data = []

#G4 data place holder
G4_mod_1_data = []
G4_mod_2_data = []


# Read GRADE-3 images and store them in placeholder
for img in G3_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_1_data.append(data)

for img in G3_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_2_data.append(data)


# Read GRADE-4 images and store them in placeholder
for img in G4_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_1_data.append(data)

for img in G4_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_2_data.append(data)

# %%
''' 
Create two array 'zeros' and 'ones' containing all zeros and ones respectively. 
Here the  zeros array serves the purpose of labels for GRADE-3 and the ones array serves the purpose of labels for GRADE-4
'''

zeros= np.zeros(len(G3_mod_1))

ones = np.ones(len(G4_mod_1))

# %%
# Combine same modalities of different GRADES for training. 

img_mod_1_data = G3_mod_1_data + G4_mod_1_data
img_mod_2_data = G3_mod_2_data + G4_mod_2_data

img_mod_1_data = np.array(img_mod_1_data)
img_mod_2_data = np.array(img_mod_2_data)

img_mod_1 = img_mod_1_data/255
img_mod_2 = img_mod_2_data/255

print(img_mod_1_data.shape, img_mod_2_data.shape)
# Out:
# (2856, 224, 224, 3) (2856, 224, 224, 3)

# %%
# Combining labels for both GRADES into one array/list

labels = np.append(zeros, ones)

# %%
# CNN model definition

model = Sequential()
model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 6)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# 2023-11-29 12:20:11.126973: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:11.174747: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:11.174826: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:11.181212: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:11.181287: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:11.181326: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:13.843672: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:13.843758: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:13.843769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-29 12:20:13.843812: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 12:20:13.843839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13535 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %%
# Compile the model

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", "Precision", "Recall", "AUC"])

# %%
comb = np.concatenate([img_mod_1, img_mod_2], axis = -1)

print("Mod 1 and Mod 2 Shape: ", comb.shape)
print("Labels Shape: ", labels.shape)
# Out:
# Mod 1 and Mod 2 Shape:  (2856, 224, 224, 6)
# Labels Shape:  (2856,)

# %%
# Randomly and evenly(stratify) Spliting the data into train and test sets 
comb_train, comb_test, comb_labels_train, comb_labels_test = train_test_split(comb, labels, stratify=labels, test_size=0.2)

# Randomly and evenly(stratify) Spliting the train data into train and validation sets
comb_train, comb_val, comb_labels_train, comb_labels_val = train_test_split(comb_train, comb_labels_train, stratify=comb_labels_train, test_size=0.25)

'''
Training data = 60%
Validation data = 20%
Test data = 20%
'''
print(comb_train.shape, comb_labels_train.shape)
print(comb_val.shape, comb_labels_val.shape)
print(comb_test.shape, comb_labels_test.shape)
# Out:
# (1713, 224, 224, 6) (1713,)
# (571, 224, 224, 6) (571,)
# (572, 224, 224, 6) (572,)

# %%
# Train the model and store the results
history = model.fit(comb_train, comb_labels_train, batch_size = 32, epochs = 20, validation_data = (comb_val, comb_labels_val))
# Out:
# Epoch 1/20
# 2023-11-29 12:20:30.970106: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8905
# 2023-11-29 12:20:34.855421: I external/local_xla/xla/service/service.cc:168] XLA service 0x4a29300 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-29 12:20:34.855486: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-11-29 12:20:34.861952: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1701240635.020506    4393 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 54/54 [==============================] - 18s 103ms/step - loss: 0.8139 - accuracy: 0.5178 - precision: 0.5240 - recall: 0.5035 - auc: 0.5198 - val_loss: 0.7151 - val_accuracy: 0.4956 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5687
# Epoch 2/20
# 54/54 [==============================] - 3s 55ms/step - loss: 0.6776 - accuracy: 0.5522 - precision: 0.5493 - recall: 0.6374 - auc: 0.5944 - val_loss: 0.6676 - val_accuracy: 0.6095 - val_precision: 0.5727 - val_recall: 0.8889 - val_auc: 0.6653
# Epoch 3/20
# 54/54 [==============================] - 3s 51ms/step - loss: 0.6100 - accuracy: 0.6649 - precision: 0.6670 - recall: 0.6732 - auc: 0.7227 - val_loss: 0.6801 - val_accuracy: 0.6200 - val_precision: 0.7710 - val_recall: 0.3507 - val_auc: 0.7638
# Epoch 4/20
# 54/54 [==============================] - 3s 60ms/step - loss: 0.5305 - accuracy: 0.7443 - precision: 0.7449 - recall: 0.7517 - auc: 0.8157 - val_loss: 0.4354 - val_accuracy: 0.7986 - val_precision: 0.8035 - val_recall: 0.7951 - val_auc: 0.8816
# Epoch 5/20
# 54/54 [==============================] - 3s 60ms/step - loss: 0.3648 - accuracy: 0.8435 - precision: 0.8345 - recall: 0.8614 - auc: 0.9190 - val_loss: 0.3877 - val_accuracy: 0.8074 - val_precision: 0.8589 - val_recall: 0.7396 - val_auc: 0.9195
# Epoch 6/20
# 54/54 [==============================] - 3s 58ms/step - loss: 0.2055 - accuracy: 0.9159 - precision: 0.9159 - recall: 0.9180 - auc: 0.9756 - val_loss: 0.1882 - val_accuracy: 0.9229 - val_precision: 0.9586 - val_recall: 0.8854 - val_auc: 0.9816
# Epoch 7/20
# 54/54 [==============================] - 3s 55ms/step - loss: 0.1361 - accuracy: 0.9521 - precision: 0.9495 - recall: 0.9561 - auc: 0.9887 - val_loss: 0.1158 - val_accuracy: 0.9492 - val_precision: 0.9331 - val_recall: 0.9688 - val_auc: 0.9920
# Epoch 8/20
# 54/54 [==============================] - 3s 56ms/step - loss: 0.0587 - accuracy: 0.9807 - precision: 0.9782 - recall: 0.9838 - auc: 0.9982 - val_loss: 0.1466 - val_accuracy: 0.9422 - val_precision: 0.9073 - val_recall: 0.9861 - val_auc: 0.9880
# Epoch 9/20
# 54/54 [==============================] - 3s 55ms/step - loss: 0.0367 - accuracy: 0.9877 - precision: 0.9840 - recall: 0.9919 - auc: 0.9995 - val_loss: 0.0907 - val_accuracy: 0.9685 - val_precision: 0.9470 - val_recall: 0.9931 - val_auc: 0.9962
# Epoch 10/20
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0316 - accuracy: 0.9895 - precision: 0.9885 - recall: 0.9908 - auc: 0.9995 - val_loss: 0.0516 - val_accuracy: 0.9807 - val_precision: 0.9860 - val_recall: 0.9757 - val_auc: 0.9984
# Epoch 11/20
# 54/54 [==============================] - 3s 54ms/step - loss: 0.0096 - accuracy: 0.9988 - precision: 0.9977 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9825 - val_precision: 0.9860 - val_recall: 0.9792 - val_auc: 0.9972
# Epoch 12/20
# 54/54 [==============================] - 3s 53ms/step - loss: 0.0042 - accuracy: 0.9994 - precision: 1.0000 - recall: 0.9988 - auc: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9860 - val_precision: 0.9828 - val_recall: 0.9896 - val_auc: 0.9975
# Epoch 13/20
# 54/54 [==============================] - 3s 57ms/step - loss: 9.0379e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9912 - val_precision: 0.9896 - val_recall: 0.9931 - val_auc: 0.9977
# Epoch 14/20
# 54/54 [==============================] - 3s 53ms/step - loss: 4.0942e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9912 - val_precision: 0.9896 - val_recall: 0.9931 - val_auc: 0.9978
# Epoch 15/20
# 54/54 [==============================] - 3s 54ms/step - loss: 2.8955e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9912 - val_precision: 0.9896 - val_recall: 0.9931 - val_auc: 0.9978
# Epoch 16/20
# 54/54 [==============================] - 3s 55ms/step - loss: 2.2584e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9979
# Epoch 17/20
# 54/54 [==============================] - 3s 57ms/step - loss: 1.7432e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9979
# Epoch 18/20
# 54/54 [==============================] - 3s 55ms/step - loss: 1.3352e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9912 - val_precision: 0.9896 - val_recall: 0.9931 - val_auc: 0.9979
# Epoch 19/20
# 54/54 [==============================] - 3s 53ms/step - loss: 1.0310e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9895 - val_precision: 0.9896 - val_recall: 0.9896 - val_auc: 0.9979
# Epoch 20/20
# 54/54 [==============================] - 3s 54ms/step - loss: 8.5750e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9912 - val_precision: 0.9930 - val_recall: 0.9896 - val_auc: 0.9979

# %%
from keras.utils import plot_model
plot_model(model)

# %%
# Evaluate model on unseen (test) data

y_pred = model.predict(comb_test)
y_pred_binary = (y_pred > 0.5).astype(int) 

# Calculate accuracy
accuracy = accuracy_score(comb_labels_test, y_pred_binary)
precision = precision_score(comb_labels_test, y_pred_binary)
recall = recall_score(comb_labels_test, y_pred_binary)
f1 = f1_score(comb_labels_test, y_pred_binary)

# Confusion matrix
conf_matrix = confusion_matrix(comb_labels_test, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 18/18 [==============================] - 1s 38ms/step
# Accuracy: 0.9965034965034965
# Precision: 0.9965397923875432
# Recall: 0.9965397923875432
# F1 Score: 0.9965397923875432
# Confusion Matrix:
# [[282   1]
#  [  1 288]]

# %%
# Loss Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Loss curve- Overall")
plt.plot(history.history["loss"], label="overall training loss")
plt.plot(history.history["val_loss"], label="overall testing loss")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Accuracy Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Accuracy curve")
plt.plot(history.history["accuracy"], label="training")
plt.plot(history.history["val_accuracy"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Precision Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Precision curve")
plt.plot(history.history["precision"], label="training")
plt.plot(history.history["val_precision"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
#Recall curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Recall curve")
plt.plot(history.history["recall"], label="training")
plt.plot(history.history["val_recall"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# AUC curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("AUC curve")
plt.plot(history.history["auc"], label="training")
plt.plot(history.history["val_auc"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()
