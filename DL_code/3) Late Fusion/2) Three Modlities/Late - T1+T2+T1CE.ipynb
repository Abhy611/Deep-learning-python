# %%
import glob
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array, load_img
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-11-29 16:08:42.578688: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 16:08:42.629488: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 16:08:42.629526: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 16:08:42.630679: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 16:08:42.638890: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 16:08:43.773093: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load modlities of GRADE 3
G3_mod_1 = glob.glob(r"GRADE-3/t1/*.png") 
G3_mod_2 = glob.glob(r"GRADE-3/t2/*.png")
G3_mod_3 = glob.glob(r"GRADE-3/t1ce/*.png")
# G3_mod_4 = glob.glob(r"GRADE-3/t1ce/*.png")

# Load modlities of GRADE 4
G4_mod_1 = glob.glob(r"GRADE-4/t1/*.png")
G4_mod_2 = glob.glob(r"GRADE-4/t2/*.png")
G4_mod_3 = glob.glob(r"GRADE-4/t1ce/*.png")
# G4_mod_4 = glob.glob(r"GRADE-4/t1ce/*.png")

#G3 data place holder
G3_mod_1_data = []
G3_mod_2_data = []
G3_mod_3_data = []
# G3_mod_4_data = []

#G4 data place holder
G4_mod_1_data = []
G4_mod_2_data = []
G4_mod_3_data = []
# G4_mod_4_data = []


# Read GRADE-3 images and store them in placeholder
for img in G3_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_1_data.append(data)

for img in G3_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_2_data.append(data)

for img in G3_mod_3:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G3_mod_3_data.append(data)
    
# for img in G3_mod_4:
#     data = cv2.imread(img, 1)
#     data = cv2.resize(data, (224, 224))
#     G3_mod_4_data.append(data)

# Read GRADE-4 images and store them in placeholder
for img in G4_mod_1:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_1_data.append(data)

for img in G4_mod_2:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_2_data.append(data)
    
for img in G4_mod_3:
    data = cv2.imread(img, 1)
    data = cv2.resize(data, (224, 224))
    G4_mod_3_data.append(data)
    
# for img in G4_mod_4:
#     data = cv2.imread(img, 1)
#     data = cv2.resize(data, (224, 224))
#     G4_mod_4_data.append(data)

# %%
''' 
Create two array 'zeros' and 'ones' containing all zeros and ones respectively. 
Here the  zeros array serves the purpose of labels for GRADE-3 and the ones array serves the purpose of labels for GRADE-4
'''

zeros= np.zeros(len(G3_mod_1))

ones = np.ones(len(G4_mod_1))

# %%
# Combine same modalities of different GRADES for training. 

img_mod_1_data = G3_mod_1_data + G4_mod_1_data
img_mod_2_data = G3_mod_2_data + G4_mod_2_data
img_mod_3_data = G3_mod_3_data + G4_mod_3_data
# img_mod_4_data = G3_mod_4_data + G4_mod_4_data

img_mod_1_data = np.array(img_mod_1_data)
img_mod_2_data = np.array(img_mod_2_data)
img_mod_3_data = np.array(img_mod_3_data)
# img_mod_4_data = np.array(img_mod_4_data)

img_mod_1 = img_mod_1_data/255
img_mod_2 = img_mod_2_data/255
img_mod_3 = img_mod_3_data/255
# img_mod_4 = img_mod_4_data/255

# print(img_mod_1_data.shape, img_mod_2_data.shape, img_mod_3_data.shape, img_mod_4_data.shape)
print(img_mod_1_data.shape, img_mod_2_data.shape, img_mod_3_data.shape)
# Out:
# (2856, 224, 224, 3) (2856, 224, 224, 3) (2856, 224, 224, 3)

# %%
# Combining labels for both GRADES into one array/list

labels = np.append(zeros, ones)

# %%
# CNN model definition
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model

# For Mod_1
model_1 = Sequential()
model_1.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 3)))
model_1.add(MaxPooling2D((2, 2)))
model_1.add(Conv2D(64, (3, 3), activation="relu"))
model_1.add(MaxPooling2D((2, 2)))
model_1.add(Conv2D(128, (3, 3), activation="relu"))
model_1.add(MaxPooling2D((2, 2)))
model_1.add(Flatten())
model_1.add(Dense(128, activation="relu"))

# For Mod_2
model_2 = Sequential()
model_2.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 3)))
model_2.add(MaxPooling2D((2, 2)))
model_2.add(Conv2D(64, (3, 3), activation="relu"))
model_2.add(MaxPooling2D((2, 2)))
model_2.add(Conv2D(128, (3, 3), activation="relu"))
model_2.add(MaxPooling2D((2, 2)))
model_2.add(Flatten())
model_2.add(Dense(128, activation="relu"))

# For Mod_3
model_3 = Sequential()
model_3.add(Conv2D(32, (3, 3), activation="relu", input_shape=(224, 224, 3)))
model_3.add(MaxPooling2D((2, 2)))
model_3.add(Conv2D(64, (3, 3), activation="relu"))
model_3.add(MaxPooling2D((2, 2)))
model_3.add(Conv2D(128, (3, 3), activation="relu"))
model_3.add(MaxPooling2D((2, 2)))
model_3.add(Flatten())
model_3.add(Dense(128, activation="relu"))

fused_features = tf.keras.layers.Concatenate()([model_1.output, model_2.output, model_3.output])

output = Dense(1, activation='sigmoid')(fused_features)

model = Model(inputs = [model_1.input, model_2.input, model_3.input], outputs = output)
# Out:
# 2023-11-29 16:09:02.417208: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:02.466919: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:02.466988: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:02.475313: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:02.475396: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:02.475435: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:05.212024: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:05.212125: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:05.212141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-29 16:09:05.212189: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-29 16:09:05.212211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13535 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.Precision(),tf.keras.metrics.Recall(),tf.keras.metrics.AUC()], run_eagerly=True)

# %%
#comb = np.concatenate([img_mod_1, img_mod_2, img_mod_3, img_mod_4], axis = -1)
# comb = img_mod_1

# print("Mod 1 and Mod 2 Shape: ", comb.shape)
# print("Labels Shape: ", labels.shape)

# %%
from sklearn.model_selection import train_test_split

img_1_train, img_1_test, labels_1_train, labels_1_test = train_test_split(img_mod_1, labels, stratify=labels, test_size=0.2, random_state = 42)
img_1_train, img_1_val, labels_1_train, labels_1_val = train_test_split(img_1_train, labels_1_train, stratify=labels_1_train, test_size=0.25, random_state = 42)

print(img_1_train.shape, labels_1_train.shape)
print(img_1_val.shape, labels_1_val.shape)
print(img_1_test.shape, labels_1_test.shape)
# Out:
# (1713, 224, 224, 3) (1713,)
# (571, 224, 224, 3) (571,)
# (572, 224, 224, 3) (572,)

# %%
img_2_train, img_2_test, labels_2_train, labels_2_test = train_test_split(img_mod_2, labels, stratify=labels, test_size=0.2, random_state = 42)
img_2_train, img_2_val, labels_2_train, labels_2_val = train_test_split(img_2_train, labels_2_train, stratify=labels_2_train, test_size=0.25, random_state = 42)

print(img_2_train.shape, labels_2_train.shape)
print(img_2_val.shape, labels_2_val.shape)
print(img_2_test.shape, labels_2_test.shape)
# Out:
# (1713, 224, 224, 3) (1713,)
# (571, 224, 224, 3) (571,)
# (572, 224, 224, 3) (572,)

# %%
from sklearn.model_selection import train_test_split

img_3_train, img_3_test, labels_3_train, labels_3_test = train_test_split(img_mod_3, labels, stratify=labels, test_size=0.2, random_state = 42)
img_3_train, img_3_val, labels_3_train, labels_3_val = train_test_split(img_3_train, labels_3_train, stratify=labels_3_train, test_size=0.25, random_state = 42)

print(img_3_train.shape, labels_3_train.shape)
print(img_3_val.shape, labels_3_val.shape)
print(img_3_test.shape, labels_3_test.shape)
# Out:
# (1713, 224, 224, 3) (1713,)
# (571, 224, 224, 3) (571,)
# (572, 224, 224, 3) (572,)

# %%
# Train the model and store the results
history = model.fit([img_1_train, img_2_train, img_3_train], [labels_1_train, labels_2_train, labels_3_train], validation_data=([img_1_val, img_2_val, img_3_val], [labels_1_val, labels_2_val, labels_3_val]),  epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 2023-11-29 16:09:21.408561: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8905
# 2023-11-29 16:09:29.205218: I external/local_xla/xla/service/service.cc:168] XLA service 0xe75710e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-29 16:09:29.205285: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-11-29 16:09:29.211655: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1701254369.399458   28419 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f735bfa6310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f735bfa6310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 54/54 [==============================] - 31s 265ms/step - loss: 0.8037 - binary_accuracy: 0.5166 - precision: 0.5212 - recall: 0.5404 - auc: 0.5236 - val_loss: 0.6817 - val_binary_accuracy: 0.6497 - val_precision: 0.7292 - val_recall: 0.4861 - val_auc: 0.7335
# Epoch 2/20
# 54/54 [==============================] - 9s 170ms/step - loss: 0.6231 - binary_accuracy: 0.6544 - precision: 0.6445 - recall: 0.7055 - auc: 0.7154 - val_loss: 0.4964 - val_binary_accuracy: 0.7793 - val_precision: 0.8092 - val_recall: 0.7361 - val_auc: 0.8772
# Epoch 3/20
# 54/54 [==============================] - 10s 178ms/step - loss: 0.3669 - binary_accuracy: 0.8447 - precision: 0.8529 - recall: 0.8372 - auc: 0.9208 - val_loss: 0.3077 - val_binary_accuracy: 0.8757 - val_precision: 0.8109 - val_recall: 0.9826 - val_auc: 0.9694
# Epoch 4/20
# 54/54 [==============================] - 9s 174ms/step - loss: 0.1586 - binary_accuracy: 0.9416 - precision: 0.9474 - recall: 0.9365 - auc: 0.9852 - val_loss: 0.1930 - val_binary_accuracy: 0.9194 - val_precision: 0.8667 - val_recall: 0.9931 - val_auc: 0.9904
# Epoch 5/20
# 54/54 [==============================] - 9s 171ms/step - loss: 0.0617 - binary_accuracy: 0.9755 - precision: 0.9747 - recall: 0.9769 - auc: 0.9985 - val_loss: 0.0438 - val_binary_accuracy: 0.9842 - val_precision: 0.9761 - val_recall: 0.9931 - val_auc: 0.9990
# Epoch 6/20
# 54/54 [==============================] - 9s 167ms/step - loss: 0.0330 - binary_accuracy: 0.9907 - precision: 0.9942 - recall: 0.9873 - auc: 0.9992 - val_loss: 0.0395 - val_binary_accuracy: 0.9842 - val_precision: 0.9929 - val_recall: 0.9757 - val_auc: 0.9992
# Epoch 7/20
# 54/54 [==============================] - 9s 169ms/step - loss: 0.0055 - binary_accuracy: 0.9988 - precision: 0.9988 - recall: 0.9988 - auc: 1.0000 - val_loss: 0.0141 - val_binary_accuracy: 0.9947 - val_precision: 0.9965 - val_recall: 0.9931 - val_auc: 0.9999
# Epoch 8/20
# 54/54 [==============================] - 10s 194ms/step - loss: 0.0017 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0129 - val_binary_accuracy: 0.9947 - val_precision: 0.9965 - val_recall: 0.9931 - val_auc: 0.9999
# Epoch 9/20
# 54/54 [==============================] - 9s 173ms/step - loss: 5.2381e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0094 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 10/20
# 54/54 [==============================] - 9s 173ms/step - loss: 2.0675e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0083 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 11/20
# 54/54 [==============================] - 10s 192ms/step - loss: 1.3561e-04 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 12/20
# 54/54 [==============================] - 10s 179ms/step - loss: 9.9039e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 13/20
# 54/54 [==============================] - 10s 178ms/step - loss: 7.2041e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0080 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 14/20
# 54/54 [==============================] - 9s 169ms/step - loss: 5.2025e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0079 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 15/20
# 54/54 [==============================] - 9s 171ms/step - loss: 3.4899e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0088 - val_binary_accuracy: 0.9947 - val_precision: 0.9965 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 16/20
# 54/54 [==============================] - 9s 166ms/step - loss: 2.5912e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0097 - val_binary_accuracy: 0.9965 - val_precision: 1.0000 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 17/20
# 54/54 [==============================] - 9s 169ms/step - loss: 1.7478e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0109 - val_binary_accuracy: 0.9947 - val_precision: 0.9965 - val_recall: 0.9931 - val_auc: 0.9999
# Epoch 18/20
# 54/54 [==============================] - 9s 165ms/step - loss: 1.3554e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0106 - val_binary_accuracy: 0.9930 - val_precision: 0.9931 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 19/20
# 54/54 [==============================] - 9s 168ms/step - loss: 1.0818e-05 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0095 - val_binary_accuracy: 0.9947 - val_precision: 0.9965 - val_recall: 0.9931 - val_auc: 1.0000
# Epoch 20/20
# 54/54 [==============================] - 9s 173ms/step - loss: 8.6720e-06 - binary_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0091 - val_binary_accuracy: 0.9930 - val_precision: 0.9931 - val_recall: 0.9931 - val_auc: 1.0000

# %%
from keras.utils import plot_model
plot_model(model)

# %%
# Evaluate model on unseen (test) data

y_pred = model.predict([img_1_test, img_2_test, img_3_test])
y_pred_binary = (y_pred > 0.5).astype(int) 

# Calculate accuracy
accuracy = accuracy_score(labels_1_test, y_pred_binary)
precision = precision_score(labels_1_test, y_pred_binary)
recall = recall_score(labels_1_test, y_pred_binary)
f1 = f1_score(labels_1_test, y_pred_binary)

# Confusion matrix
conf_matrix = confusion_matrix(labels_1_test, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 18/18 [==============================] - 1s 81ms/step
# Accuracy: 0.993006993006993
# Precision: 0.9930795847750865
# Recall: 0.9930795847750865
# F1 Score: 0.9930795847750865
# Confusion Matrix:
# [[281   2]
#  [  2 287]]

# %%
# Loss Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Loss curve- Overall")
plt.plot(history.history["loss"], label="overall training loss")
plt.plot(history.history["val_loss"], label="overall testing loss")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Accuracy Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Accuracy curve")
plt.plot(history.history["binary_accuracy"], label="training")
plt.plot(history.history["val_binary_accuracy"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# Precision Curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Precision curve")
plt.plot(history.history["precision"], label="training")
plt.plot(history.history["val_precision"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
#Recall curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("Recall curve")
plt.plot(history.history["recall"], label="training")
plt.plot(history.history["val_recall"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
# AUC curve

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title("AUC curve")
plt.plot(history.history["auc"], label="training")
plt.plot(history.history["val_auc"], label="testing")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()
